# %%
#integers
abc = 6
cde = 10
total = abc + cde
print(type(total))
# Out:
# <class 'int'>

# %%
#float

a = 6.4
b =6
c= a+b
print(type(c))
print(c)
# Out:
# <class 'float'>
# 12.4

# %%
#complex
a = 2+3j
b = 6
c = a+b
print(c)
# Out:
# (8+3j)

# %%
name = input("enter your name:")
age = input("enter your age:")
print("My name is " + name + " and my age is "+ age)
# Out:
# My name is rishi and my age is 21
