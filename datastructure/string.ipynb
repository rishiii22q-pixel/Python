# %%
a ="rishi"
print(a)
# Out:
# rishi

# %%
a = """rishi"""
print(a)
# Out:
# rishi

# %%
a ="ArithmeticError"
print(a[-1:-6])

# %%
a ="Imagineable"
#print(a[5])

print(a[2:10:2])

print(a.upper())
print(a.lower())
print(a.replace("Imagineable","Rishi"))
# Out:
# aieb
# IMAGINEABLE
# imagineable
# Rishi

# %%
#joins

a =["apple"," banana", "cherry"]
print(",".join(a))
# Out:
# apple, banana,cherry

# %%
#strip
a ="  python java   "
print(a.strip())
# Out:
# python java

# %%
#find
a ="python"
print(a.find("h"))
print(a.find("tho"))
# Out:
# 3
# 2

# %%
#count
a ="pythhhhon"
print(a.count("h"))
# Out:
# 4

# %%
#startswith
email = "rishi@gmail.com"
print(email.startswith("rish"))
# Out:
# True

# %%
#endswith
a ="rishi@gmail.com"
print(a.endswith("@"))
print(a.endswith(".com"))
# Out:
# False
# True

# %%
#isdigit
a ="38930"
print(a.isdigit())
# Out:
# True

# %%
#isalpha
a ="ejnfis"
print(a.isalpha())
# Out:
# True

# %%
#isalnum
a ="302ojio"
print(a.isalnum())
# Out:
# True

# %%
#Captalize
a ="python programming"
print(a.capitalize())
# Out:
# Python programming

# %%
#title
a ="python program"
print(a.title())
# Out:
# Python Program

# %%
#Swapcase
a = "pyTHON"
print(a.swapcase())
# Out:
# PYthon

# %%
#in operator

name = "python"
print("py" in name)
# Out:
# True

# %%
#split
a = "apple banana cherry"
print(a.split())
# Out:
# ['apple', 'banana', 'cherry']
