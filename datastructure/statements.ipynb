# %%
#A conditional statement is used to execute different blocks of code depending on whether a condition is true or false

# %%
a = int(input("Enter the value"))
if a >=20:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
#eLif

a = int(input("Enter a value:"))
b = int(input("Enter b value"))
c =int(input("Enter c value"))

if a > b:
    print("A is greater")
elif b > a:
    print("B is greater")
elif c > a:
    print("C is greater")
else:
    print("No one is greater")
# Out:
# B is greater

# %%
#nested if - it means one if statement inside another if statement 

"""a = int(input("Enter a value:"))
b =int(input("Enter b value:"))

if a >= b:
    if b>=a:
     print("Passed")"""



Mark = int(input("Enter the mark:"))
attendance = int(input("Enter the attendance percentage:"))

if Mark >= 50:
    if attendance >=75:
        print("Eligible")
    else:
        print("Attendance is low")
        
else:
    print("NOT ELIGIBLE")
# Out:
# Attendance is low

# %%
age = int(input("enter the age"))
#salary = int(input("enter the salary"))


"""if age >= 21 or salary >= 25000:
    print("Eligible")
else:
    print("Not Eligible")"""

if not age >=21 :
    print("NOT ELIGIBLE")
else:
    print("Eligible")
# Out:
# NOT ELIGIBLE

# %%
a = 8
b =8 

if a>10 or b > 10:
    print("Passed")
else:
    print("Not Passed")
# Out:
# Not Passed

# %%
#ternary - a conditional expression is a short way to write a simple if else statement in one line


age = 21
"""a = "adult" if age > 20 else "Minor"
print(a)"""

b ="passed" if age > 20 else " none" if age > 20 else "NA"

# %%
age = int(input("Enter the value"))

a = "eligible" if age > 21 else "none" if age > 15 else "NA" 
print(a)
# Out:
# eligible
