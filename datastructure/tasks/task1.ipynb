# %%
#Student name list

StudentNames =["Rishi", "Abinash", "Praveen", "Santhosh","Priya"]

N = input("Enter name:")

if N in StudentNames:
    print("Student Found")
else:
    print("Student Not Found")
# Out:
# Student Found

# %%
Marks = input("Enter the marks:")
print("Marks:", Marks)

oldmark =input("enter the mark you want to change:")
newmark=input("enter the new mark:")

change = Marks.replace(oldmark,newmark)

list = [change]
print("New Marks:", list)
#print("New Marks:", change)
# Out:
# Marks: 100 90 55 85 78
# New Marks: ['100 77 55 85 78']

# %%
#shopping list

ShoppingList = input("Enter the shopping list").split(" ")

print(ShoppingList)

itemtobeadded = input("Enter the Item")
ShoppingList.append(itemtobeadded)
print("updated shopping list:", ShoppingList)
# Out:
# ['rice', 'milk', 'water', 'oil']
# updated shopping list: ['rice', 'milk', 'water', 'oil', 'milkshake']

# %%
#StringLength

name =input("Enter the name:")
print(len(name))
# Out:
# 5

# %%
#FirstandLastCharacter

Word =input("Enter the word:")

print(Word[0])
print(Word[-1])
# Out:
# R
# i

# %%
#StringSlicing

language = input("Enter the language:")
print(language)

print("first 3 letters:",language[:3])
print("last 3 letters:",language[-3:])
print("Position 2 to 5:",language[1:5:])
# Out:
# Programming
# first 3 letters: Pro
# last 3 letters: ing
# Position 2 to 5: rogr
